# %%
import numpy as np
import matplotlib.pyplot as plt

datafile = '5_lidar.csv'

time, \
x, \
y, \
z = np.loadtxt(datafile, delimiter=',', unpack=True, skiprows=1)

print('Read \'%s\' successfully.' % datafile)
# Out:
# Read '5_lidar.csv' successfully.

# %%
fig = plt.figure(figsize=(16,12))
# Measurements
plt.plot(x,y, label='LiDAR Measurements', c='k', lw=5)

# %%
datafile = '2_gnssGT.csv'

time, \
gx, \
gy, \
gz = np.loadtxt(datafile, delimiter=',', unpack=True, skiprows=1)

print('Read \'%s\' successfully.' % datafile)
# Out:
# Read '2_gnssGT.csv' successfully.

# %%
fig = plt.figure(figsize=(16,12))
# Measurements
plt.plot(gx,gy, label='GNSS Measurements', c='k', lw=5)

# %%
datafile = '3_gnss.csv'

time, \
ggx, \
ggy, \
ggz = np.loadtxt(datafile, delimiter=',', unpack=True, skiprows=1)

print('Read \'%s\' successfully.' % datafile)
# Out:
# Read '3_gnss.csv' successfully.

# %%
fig = plt.figure(figsize=(16,12))
# Measurements
plt.plot(ggx,ggy, label='GNSS Measurements', c='k', lw=5)
